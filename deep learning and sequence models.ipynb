# %% [markdown]
# ##deep neural network brief:
#  this is the learning that copyies how the brain functions.
# It is a subset of machine learning and is called deep learning
# because it makes use of deep neural networks.
#
# for all algorithms it has:
# -input layer
# -hidden layer
# -output layer
# the inptu layer accepts many inputs of data and operates in   multiple
# layers to produce the  desired output.
# thus the following  steps are used in the deep learniig process
# :
# 1.understand the problem
# 2.identify the data
# 3.select the deep learning algorigthm
# 4.train the model
# 5.test the model
#
# The learning occurs in two phases.
# 1.The first phase consists of applying a nonlinear transformation of the
# input and create a statistical model as output.
# 2.The second phase aims at improving the model with a mathematical method
# known as derivative.
# thus the neural network repeats these two phases via itaretion 100 to 1000 times
# till when the accurate output is produced.
#
# classification of neural network
# -shallow neural network(has on hidden layer between the input and output layer)
#
# -deep neural network(has more than one hidden layer between the input and
# output layer)
#
# Types of deep neural newtork are:
# 1.Feed-forward neural network
#    -its the simplest and has the flow in one direction,meaning the flow stars at the
#    input then to the hidden layer the to the outputlayer,this means there is no
#    loop in this neural network thus the flow of info stops at the output layer.
#
# 2.Recurrent neural network
#    -its a multilayer that its data flow in sequences thus it involves loops.
# Common uses of RNN
# -Help securities traders to generate analytic reports
# -Detect abnormalities in the contract of financial statement
# -Detect fraudulent credit-card transaction
# -Provide a caption for images
# -Power chatbots
# -The standard uses of RNN occur when the practitioners are working with
# time-series data or sequences (e.g., audio recordings or text).
#
# 3.Convolution neural network
#    -its used for more complex features mostly used for unstructed dataset
# and the practitioner need to extract information from it.
# consider the following example:
# For instance, if the task is to predict an image caption:
# 1.The CNN receives an image of let's say a cat, this image, in computer term,
#  is a collection of the pixel. Generally, one layer for the greyscale picture
#  and three layers for a color picture.
# 2.During the feature learning (i.e., hidden layers), the network will identify
#   unique features, for instance, the tail of the cat, the ear, etc.
# 3.When the network thoroughly learned how to recognize a picture, it can provide
#   a probability for each image it knows. The label with the highest probability
#   will become the prediction of the network.
#
#  THE REINFORCEMENT LEARNING
# this is the subfield in machine learning that the system is trained to receive
# rewards or punishment be learning from trail and error.
# this is used even in video games to improve the gaming experience to provide the
# smarter bot.
# some algorithms used are:
# 1.Q-learning
# 2.Deep Qnetwork
# 3.State Action-reward-state-action
# 4.Deep deterministic policy gradient
#
# some applications of deep learning are in finance,HR,and even marketing
#
# deep learning is important because it
#  -help to predict the actionable results,
#  -it predicts the most accurate value even for unsupervised data.
# some limitations of deep learning are
#  -hard in data labeling
#  -obtain huge triaining  datasets so as to give an accurate output.
#  -can't explain a problem like a human being
#
# below
# There are various sequence models in the deep learning domain,let’s see
#  the applications we can apply these models to.
# 1.Speech recognition:
#      Input: audio clip -> Output: text
# 2.Music generation:
#     Input: integer referring to genre (or an empty set) -> Output: music
# 3.Sentiment classification:
#       Input: text -> Output: ratings
# 4.DNA sequence analysis:
#      Input: DNA (alphabet) -> Output: label part of the DNA sequence
# 5.Machine translation:
#      Input: text -> Output: text translation
# 6.Video activity recognition:
#      Input: video frames -> Output: identification of the activity
# 7.Name entity recognition:
#     Input: sentence -> Output: identify people within it.
